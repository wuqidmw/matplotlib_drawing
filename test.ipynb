# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib as mpl
import EncapsulationPy_PieCharts

plt.rcParams["font.family"] = ["Times New Roman", "STKaiti"]
mpl.rcParams['axes.unicode_minus'] = False
import EncapsulationPy_ViolinDiagram
import EncapsulationPy_BoxPlot
import importlib  

importlib.reload(EncapsulationPy_BoxPlot)
# Out:
# <module 'EncapsulationPy_BoxPlot' from 'C:\\Users\\Wu\\Documents\\GitHub\\EncapsulationPy_BoxPlot.py'>

# %%
file_path = r'C:\Users\Wu\Desktop\shache.csv'
df = pd.read_csv(file_path, encoding='utf-8', header=None)

# %%
df = df.fillna(0)
df = df[df[0] != 0]

# %%
EncapsulationPy_BoxPlot.get_boxplot(data=df[0], tick_labels=['刹车力'], y_label=None, title='刹车力箱形图',
                                    vert=True, figsize=(8, 8), sub_title="M36T")
# Out:
# {'90%': np.float64(1040.1), '25%': np.float64(17.9), '50%': np.float64(49.9), '75%': np.float64(347.5)}
# C:\Users\Wu\Documents\GitHub\box.py:103: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig(sanitize_and_check_filename(title) + '.png')

# %%
file_path = r'C:\Users\Wu\Desktop\xhaiba.csv'
df = pd.read_csv(file_path, encoding='utf-8', header=None,skiprows=[0])

# %%
# max_index = df.idxmax()  
# df.drop(max_index, inplace=True)  
df.dropna(inplace=True)


df = df[df.iloc[:, 0] <= 6891]  
# 输出筛选后的数据

# %%
EncapsulationPy_BoxPlot.get_boxplot(data=df[0], tick_labels=['GPS海拔'], y_label=None, title='GPS海拔箱形图',
                                    vert=True, figsize=(8, 8), sub_title="M36T")
# Out:
# {'90%': np.float64(1040.1), '25%': np.float64(17.9), '50%': np.float64(49.9), '75%': np.float64(347.5)}
# get_boxplot 运行时间: 25.3012 秒

# %%
file_path = r'C:\Users\Wu\Desktop\xhaiba.csv'
df = pd.read_csv(file_path, encoding='utf-8', header=None,skiprows=[0])

# %%
# df.dropna(inplace=True)
# df = df[df.iloc[:, 0] <= 6891]
data = np.random.normal(0, 1.5, 6971)

# %%
importlib.reload(EncapsulationPy_ViolinDiagram)
# df.dropna(inplace=True)
EncapsulationPy_ViolinDiagram.custom_violinplot(data, position=1, figsize=(8, 8),
                            title='随机抽取数据(图形展示)', x_label='ViolinDiagram',y_label="数值", sub_title="车型：M36T")

# %%
file_path = r'C:\Users\Wu\Desktop\seat_heating2.xlsx'
df1 = pd.read_excel(file_path, header=None, sheet_name="driver_stats", skiprows=[0]) 
df2 = pd.read_excel(file_path, header=None, sheet_name="passenger_stats", skiprows=[0])

# %%
importlib.reload(EncapsulationPy_ViolinDiagram)
df1.dropna(inplace=True)
df2.dropna(inplace=True)
EncapsulationPy_ViolinDiagram.custom_violinplots(df1[3], df2[3],  figsize=(18, 12),
                            title='主副驾驶加热时间', x_labels=['主驾驶加热时间', '副驾驶加热时间'], 
                            sub_titles=['车型：M36T', '车型：M36T'])

# %%
file_path = r'C:\Users\Wu\Desktop\zhuansu.csv'
df = pd.read_csv(file_path, encoding='utf-8', header=None, skiprows=[0])

# %%
# max_index = df.idxmax()  
# df.drop(max_index, inplace=True)  
df.dropna(inplace=True)

# %%
importlib.reload(EncapsulationPy_BoxPlot)
EncapsulationPy_BoxPlot.get_boxplot(data=df[0], tick_labels=['发动机转速'], y_label=None, title='发动机转速箱形图',
                                    vert=True, figsize=(8, 8), sub_title="车型：M36T", dcm = 2)
# Out:
# {'90%': np.float64(1792.0), '25%': np.float64(701.0), '50%': np.float64(1098.0), '75%': np.float64(1458.0)}
# get_boxplot 运行时间: 33.8872 秒

# %%
file_path = r'C:\Users\Wu\Desktop\seat_heating2.xlsx'
df = pd.read_excel(file_path, header=None, sheet_name="passenger_stats", skiprows=[0])

# %%
df.dropna(inplace=True)

# %%
importlib.reload(EncapsulationPy_BoxPlot)
EncapsulationPy_BoxPlot.get_boxplot(data=df[3], tick_labels=['副驾驶加热时间箱形图'], y_label=None, title='副驾驶加热时间箱形图',
                                    vert=True, figsize=(8, 8), sub_title="M36T")
# Out:
# {'90%': np.float64(2570.0), '25%': np.float64(270.0), '50%': np.float64(740.0), '75%': np.float64(1470.0)}
# get_boxplot 运行时间: 0.3723 秒

# %%
file_path = r'C:\Users\Wu\Desktop\seat_heating.xlsx'
df = pd.read_excel(file_path, header=None, sheet_name="passenger_stats", skiprows=[0])
df.dropna(inplace=True)

# %%
importlib.reload(EncapsulationPy_BoxPlot)
EncapsulationPy_BoxPlot.get_boxplot(data=df[3], tick_labels=['time_diff'], y_label=None, title='副驾驶加热时间箱形图', vert=True, figsize=(8, 8), sub_title="车型：M36T",dcm=0)
# Out:
# {'90%': np.float64(2580.0), '25%': np.float64(271.0), '50%': np.float64(740.0), '75%': np.float64(1476.0)}
# get_boxplot 运行时间: 0.3124 秒

# %%
importlib.reload(EncapsulationPy_ViolinDiagram)

file_path = r'C:\Users\Wu\Desktop\seat_heating.xlsx'
df = pd.read_excel(file_path, header=None, sheet_name="passenger_stats", skiprows=[0])

show_labels={}
show_labels[1]='一月'
show_labels[2]='二月'
show_labels[3]='三月'
show_labels[4]='四月'
show_labels[5]='五月'
show_labels[6]='六月'
show_labels[7]='七月'
show_labels[8]='八月'
show_labels[9]='九月'
show_labels[10]='十月'
show_labels[11]='十一月'
show_labels[12]='十二月'

# %%
importlib.reload(EncapsulationPy_ViolinDiagram)
EncapsulationPy_ViolinDiagram.get_pie(data=df[4],title='副驾驶加热使用月份饼图',sub_title='车型：M36T ',show_labels=show_labels, figsize=(10, 10), show_zero=True)
# Out:
# get_boxplot 运行时间: 0.6127 秒
